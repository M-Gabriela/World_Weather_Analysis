# %%
#Deliverable 1. Retrieve Weather Data

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime
# Import the time module.
import time

# %%
#3 Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
#4 Get the nearest city using the citipy module.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 758

# %%
#5 Perform an API call with the OpenWeatherMap.
import requests

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=db271b578383d9969a7095867f531d51

# %%
#6 Retrieve the following information from the API ca
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description, 
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | sola
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | bongandanga
# Processing Record 4 of Set 1 | port alfred
# Processing Record 5 of Set 1 | mahebourg
# Processing Record 6 of Set 1 | new norfolk
# Processing Record 7 of Set 1 | souillac
# Processing Record 8 of Set 1 | airai
# Processing Record 9 of Set 1 | albany
# Processing Record 10 of Set 1 | omsukchan
# Processing Record 11 of Set 1 | san quintin
# Processing Record 12 of Set 1 | rocha
# Processing Record 13 of Set 1 | dikson
# Processing Record 14 of Set 1 | tilichiki
# Processing Record 15 of Set 1 | sao filipe
# Processing Record 16 of Set 1 | laibin
# Processing Record 17 of Set 1 | ilulissat
# Processing Record 18 of Set 1 | conde
# Processing Record 19 of Set 1 | ribeira grande
# Processing Record 20 of Set 1 | vaini
# Processing Record 21 of Set 1 | berdigestyakh
# Processing Record 22 of Set 1 | avarua
# Processing Record 23 of Set 1 | butaritari
# Processing Record 24 of Set 1 | geraldton
# Processing Record 25 of Set 1 | lasa
# Processing Record 26 of Set 1 | atuona
# Processing Record 27 of Set 1 | bambous virieux
# Processing Record 28 of Set 1 | gamboula
# Processing Record 29 of Set 1 | amudalavalasa
# Processing Record 30 of Set 1 | kaitangata
# Processing Record 31 of Set 1 | haibowan
# City not found. Skipping...
# Processing Record 32 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 33 of Set 1 | hithadhoo
# Processing Record 34 of Set 1 | barawe
# City not found. Skipping...
# Processing Record 35 of Set 1 | lebu
# Processing Record 36 of Set 1 | castro
# Processing Record 37 of Set 1 | nome
# Processing Record 38 of Set 1 | nanortalik
# Processing Record 39 of Set 1 | east london
# Processing Record 40 of Set 1 | mataura
# Processing Record 41 of Set 1 | daru
# Processing Record 42 of Set 1 | tommot
# Processing Record 43 of Set 1 | qaanaaq
# Processing Record 44 of Set 1 | staryy nadym
# Processing Record 45 of Set 1 | tiznit
# Processing Record 46 of Set 1 | te anau
# Processing Record 47 of Set 1 | marsabit
# Processing Record 48 of Set 1 | mongu
# Processing Record 49 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 50 of Set 1 | homer
# Processing Record 1 of Set 2 | cidreira
# Processing Record 2 of Set 2 | kulhudhuffushi
# Processing Record 3 of Set 2 | ushuaia
# Processing Record 4 of Set 2 | hobart
# Processing Record 5 of Set 2 | sao joao da barra
# Processing Record 6 of Set 2 | bredasdorp
# Processing Record 7 of Set 2 | saint-joseph
# Processing Record 8 of Set 2 | nioro
# Processing Record 9 of Set 2 | huarmey
# Processing Record 10 of Set 2 | aden
# Processing Record 11 of Set 2 | tura
# Processing Record 12 of Set 2 | santa rita
# Processing Record 13 of Set 2 | kutum
# Processing Record 14 of Set 2 | iqaluit
# Processing Record 15 of Set 2 | puerto ayora
# Processing Record 16 of Set 2 | tuktoyaktuk
# Processing Record 17 of Set 2 | bluff
# Processing Record 18 of Set 2 | chapais
# Processing Record 19 of Set 2 | ambilobe
# Processing Record 20 of Set 2 | balsas
# Processing Record 21 of Set 2 | arroyo
# Processing Record 22 of Set 2 | kapaa
# Processing Record 23 of Set 2 | hermanus
# Processing Record 24 of Set 2 | tasiilaq
# Processing Record 25 of Set 2 | thompson
# Processing Record 26 of Set 2 | asayita
# City not found. Skipping...
# Processing Record 27 of Set 2 | aksu
# Processing Record 28 of Set 2 | churapcha
# Processing Record 29 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 30 of Set 2 | tual
# Processing Record 31 of Set 2 | rikitea
# Processing Record 32 of Set 2 | lorengau
# Processing Record 33 of Set 2 | arraial do cabo
# Processing Record 34 of Set 2 | bud
# Processing Record 35 of Set 2 | iskateley
# Processing Record 36 of Set 2 | cape town
# Processing Record 37 of Set 2 | port hedland
# Processing Record 38 of Set 2 | norman wells
# Processing Record 39 of Set 2 | yellowknife
# Processing Record 40 of Set 2 | hami
# Processing Record 41 of Set 2 | vao
# Processing Record 42 of Set 2 | rosarito
# Processing Record 43 of Set 2 | rolla
# Processing Record 44 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 45 of Set 2 | camalu
# Processing Record 46 of Set 2 | vostok
# Processing Record 47 of Set 2 | jamestown
# Processing Record 48 of Set 2 | chuy
# Processing Record 49 of Set 2 | lauterbach
# Processing Record 50 of Set 2 | tavda
# Processing Record 1 of Set 3 | meyungs
# City not found. Skipping...
# Processing Record 2 of Set 3 | cabo san lucas
# Processing Record 3 of Set 3 | saint-philippe
# Processing Record 4 of Set 3 | estevan
# Processing Record 5 of Set 3 | coihaique
# Processing Record 6 of Set 3 | ponta do sol
# Processing Record 7 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 8 of Set 3 | kawhia
# Processing Record 9 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 10 of Set 3 | piacabucu
# Processing Record 11 of Set 3 | klaksvik
# Processing Record 12 of Set 3 | yanji
# Processing Record 13 of Set 3 | cap-aux-meules
# Processing Record 14 of Set 3 | faanui
# Processing Record 15 of Set 3 | santa cruz
# Processing Record 16 of Set 3 | khash
# Processing Record 17 of Set 3 | fortuna
# Processing Record 18 of Set 3 | bethel
# Processing Record 19 of Set 3 | kichera
# Processing Record 20 of Set 3 | tiksi
# Processing Record 21 of Set 3 | little current
# Processing Record 22 of Set 3 | saldanha
# Processing Record 23 of Set 3 | muisne
# Processing Record 24 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 25 of Set 3 | plettenberg bay
# Processing Record 26 of Set 3 | busselton
# Processing Record 27 of Set 3 | bathsheba
# Processing Record 28 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 29 of Set 3 | alta floresta
# Processing Record 30 of Set 3 | tezu
# Processing Record 31 of Set 3 | kokkola
# Processing Record 32 of Set 3 | evensk
# Processing Record 33 of Set 3 | dzhubga
# Processing Record 34 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 35 of Set 3 | viligili
# City not found. Skipping...
# Processing Record 36 of Set 3 | burnie
# Processing Record 37 of Set 3 | verkhnevilyuysk
# Processing Record 38 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 39 of Set 3 | madera
# Processing Record 40 of Set 3 | havelock
# Processing Record 41 of Set 3 | dali
# Processing Record 42 of Set 3 | la oroya
# Processing Record 43 of Set 3 | finnsnes
# Processing Record 44 of Set 3 | clyde river
# Processing Record 45 of Set 3 | ola
# Processing Record 46 of Set 3 | carnarvon
# Processing Record 47 of Set 3 | los llanos de aridane
# Processing Record 48 of Set 3 | kosonsoy
# Processing Record 49 of Set 3 | mizpe ramon
# City not found. Skipping...
# Processing Record 50 of Set 3 | saint george
# Processing Record 1 of Set 4 | irtyshskiy
# Processing Record 2 of Set 4 | bonavista
# Processing Record 3 of Set 4 | opotiki
# Processing Record 4 of Set 4 | narsaq
# Processing Record 5 of Set 4 | vardo
# Processing Record 6 of Set 4 | san patricio
# Processing Record 7 of Set 4 | jayanca
# Processing Record 8 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 9 of Set 4 | esperance
# Processing Record 10 of Set 4 | puerto quijarro
# Processing Record 11 of Set 4 | fairbanks
# Processing Record 12 of Set 4 | thinadhoo
# Processing Record 13 of Set 4 | poddorye
# Processing Record 14 of Set 4 | darnah
# Processing Record 15 of Set 4 | caravelas
# Processing Record 16 of Set 4 | ordynskoye
# Processing Record 17 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 18 of Set 4 | muros
# Processing Record 19 of Set 4 | dingle
# Processing Record 20 of Set 4 | antanifotsy
# Processing Record 21 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 22 of Set 4 | barrow
# Processing Record 23 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 24 of Set 4 | hilo
# Processing Record 25 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 26 of Set 4 | kashi
# Processing Record 27 of Set 4 | aklavik
# Processing Record 28 of Set 4 | zorritos
# Processing Record 29 of Set 4 | naze
# Processing Record 30 of Set 4 | constitucion
# Processing Record 31 of Set 4 | san andres
# Processing Record 32 of Set 4 | banepa
# Processing Record 33 of Set 4 | nguiu
# City not found. Skipping...
# Processing Record 34 of Set 4 | tombouctou
# Processing Record 35 of Set 4 | aflu
# City not found. Skipping...
# Processing Record 36 of Set 4 | mykhaylivka
# Processing Record 37 of Set 4 | rio gallegos
# Processing Record 38 of Set 4 | show low
# Processing Record 39 of Set 4 | sibu
# Processing Record 40 of Set 4 | fukue
# Processing Record 41 of Set 4 | orebro
# Processing Record 42 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 43 of Set 4 | pleasanton
# Processing Record 44 of Set 4 | namibe
# Processing Record 45 of Set 4 | doume
# Processing Record 46 of Set 4 | pointe michel
# Processing Record 47 of Set 4 | karratha
# Processing Record 48 of Set 4 | cabinda
# Processing Record 49 of Set 4 | kodiak
# Processing Record 50 of Set 4 | ocos
# Processing Record 1 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 2 of Set 5 | sinnamary
# Processing Record 3 of Set 5 | seminole
# Processing Record 4 of Set 5 | batagay-alyta
# Processing Record 5 of Set 5 | henties bay
# Processing Record 6 of Set 5 | buta
# Processing Record 7 of Set 5 | khandagayty
# Processing Record 8 of Set 5 | kieta
# Processing Record 9 of Set 5 | komsomolskiy
# Processing Record 10 of Set 5 | mar del plata
# Processing Record 11 of Set 5 | malakal
# Processing Record 12 of Set 5 | cayenne
# Processing Record 13 of Set 5 | salalah
# Processing Record 14 of Set 5 | bubaque
# Processing Record 15 of Set 5 | eureka
# Processing Record 16 of Set 5 | lagoa
# Processing Record 17 of Set 5 | khatanga
# Processing Record 18 of Set 5 | hudson bay
# Processing Record 19 of Set 5 | biryusinsk
# Processing Record 20 of Set 5 | kitimat
# Processing Record 21 of Set 5 | ugoofaaru
# Processing Record 22 of Set 5 | vadso
# Processing Record 23 of Set 5 | alangayam
# Processing Record 24 of Set 5 | kostomuksha
# Processing Record 25 of Set 5 | saint-augustin
# Processing Record 26 of Set 5 | portland
# Processing Record 27 of Set 5 | provideniya
# Processing Record 28 of Set 5 | flin flon
# Processing Record 29 of Set 5 | kihei
# Processing Record 30 of Set 5 | charlottesville
# Processing Record 31 of Set 5 | hervey bay
# Processing Record 32 of Set 5 | neiafu
# Processing Record 33 of Set 5 | san jose
# Processing Record 34 of Set 5 | bay roberts
# Processing Record 35 of Set 5 | mayo
# Processing Record 36 of Set 5 | torbay
# Processing Record 37 of Set 5 | roquetas de mar
# Processing Record 38 of Set 5 | tawang
# Processing Record 39 of Set 5 | qingdao
# Processing Record 40 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 41 of Set 5 | bandarbeyla
# Processing Record 42 of Set 5 | bamiantong
# Processing Record 43 of Set 5 | nabire
# Processing Record 44 of Set 5 | bosaso
# Processing Record 45 of Set 5 | upernavik
# Processing Record 46 of Set 5 | zhangjiakou
# Processing Record 47 of Set 5 | zwedru
# Processing Record 48 of Set 5 | bambanglipuro
# Processing Record 49 of Set 5 | talnakh
# Processing Record 50 of Set 5 | port macquarie
# Processing Record 1 of Set 6 | ino
# Processing Record 2 of Set 6 | cairns
# Processing Record 3 of Set 6 | dicabisagan
# Processing Record 4 of Set 6 | ahipara
# Processing Record 5 of Set 6 | tillabery
# City not found. Skipping...
# Processing Record 6 of Set 6 | merauke
# Processing Record 7 of Set 6 | longhua
# Processing Record 8 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 9 of Set 6 | takaka
# Processing Record 10 of Set 6 | boden
# Processing Record 11 of Set 6 | luderitz
# Processing Record 12 of Set 6 | novoagansk
# Processing Record 13 of Set 6 | tidore
# City not found. Skipping...
# Processing Record 14 of Set 6 | okato
# Processing Record 15 of Set 6 | rantauprapat
# Processing Record 16 of Set 6 | victoria
# Processing Record 17 of Set 6 | topeka
# Processing Record 18 of Set 6 | strezhevoy
# Processing Record 19 of Set 6 | haines junction
# Processing Record 20 of Set 6 | qaqortoq
# Processing Record 21 of Set 6 | poum
# Processing Record 22 of Set 6 | ponta delgada
# Processing Record 23 of Set 6 | turka
# Processing Record 24 of Set 6 | loviisa
# Processing Record 25 of Set 6 | belene
# Processing Record 26 of Set 6 | martapura
# Processing Record 27 of Set 6 | bure
# Processing Record 28 of Set 6 | soyo
# Processing Record 29 of Set 6 | parabel
# Processing Record 30 of Set 6 | rohru
# Processing Record 31 of Set 6 | alice springs
# Processing Record 32 of Set 6 | utinga
# Processing Record 33 of Set 6 | lavrentiya
# Processing Record 34 of Set 6 | georgetown
# Processing Record 35 of Set 6 | wenling
# Processing Record 36 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 37 of Set 6 | miles city
# Processing Record 38 of Set 6 | puerto narino
# Processing Record 39 of Set 6 | grand centre
# City not found. Skipping...
# Processing Record 40 of Set 6 | tripoli
# Processing Record 41 of Set 6 | sarangani
# Processing Record 42 of Set 6 | eydhafushi
# Processing Record 43 of Set 6 | maceio
# Processing Record 44 of Set 6 | pisco
# Processing Record 45 of Set 6 | chokurdakh
# Processing Record 46 of Set 6 | umm lajj
# Processing Record 47 of Set 6 | port elizabeth
# Processing Record 48 of Set 6 | margate
# Processing Record 49 of Set 6 | pitimbu
# Processing Record 50 of Set 6 | fairmont
# Processing Record 1 of Set 7 | yenagoa
# Processing Record 2 of Set 7 | berlevag
# Processing Record 3 of Set 7 | mugur-aksy
# Processing Record 4 of Set 7 | guira de melena
# Processing Record 5 of Set 7 | carutapera
# Processing Record 6 of Set 7 | srednekolymsk
# Processing Record 7 of Set 7 | pevek
# Processing Record 8 of Set 7 | whitewater
# Processing Record 9 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 10 of Set 7 | jalu
# Processing Record 11 of Set 7 | sept-iles
# Processing Record 12 of Set 7 | paso del toro
# Processing Record 13 of Set 7 | cedar city
# Processing Record 14 of Set 7 | azul
# Processing Record 15 of Set 7 | urumqi
# Processing Record 16 of Set 7 | ornskoldsvik
# Processing Record 17 of Set 7 | palana
# Processing Record 18 of Set 7 | praia da vitoria
# Processing Record 19 of Set 7 | acapulco
# Processing Record 20 of Set 7 | pericos
# Processing Record 21 of Set 7 | sinjar
# Processing Record 22 of Set 7 | yamethin
# Processing Record 23 of Set 7 | darhan
# Processing Record 24 of Set 7 | nemuro
# Processing Record 25 of Set 7 | panlaitan
# Processing Record 26 of Set 7 | isaka
# Processing Record 27 of Set 7 | punta de bombon
# Processing Record 28 of Set 7 | sembakung
# Processing Record 29 of Set 7 | touros
# Processing Record 30 of Set 7 | mareeba
# Processing Record 31 of Set 7 | formosa
# Processing Record 32 of Set 7 | anahuac
# Processing Record 33 of Set 7 | tokonou
# Processing Record 34 of Set 7 | sitka
# Processing Record 35 of Set 7 | kavaratti
# Processing Record 36 of Set 7 | pushkinskiye gory
# Processing Record 37 of Set 7 | kahului
# Processing Record 38 of Set 7 | novyye gorki
# Processing Record 39 of Set 7 | oyem
# Processing Record 40 of Set 7 | yenangyaung
# Processing Record 41 of Set 7 | atambua
# Processing Record 42 of Set 7 | zhigansk
# Processing Record 43 of Set 7 | laguna
# Processing Record 44 of Set 7 | promyshlennaya
# Processing Record 45 of Set 7 | severo-kurilsk
# Processing Record 46 of Set 7 | maxixe
# Processing Record 47 of Set 7 | jiwani
# Processing Record 48 of Set 7 | pousat
# City not found. Skipping...
# Processing Record 49 of Set 7 | troitsko-pechorsk
# Processing Record 50 of Set 7 | gweta
# Processing Record 1 of Set 8 | antofagasta
# Processing Record 2 of Set 8 | san cristobal
# Processing Record 3 of Set 8 | kapuskasing
# Processing Record 4 of Set 8 | bacuit
# City not found. Skipping...
# Processing Record 5 of Set 8 | llallagua
# Processing Record 6 of Set 8 | mount isa
# Processing Record 7 of Set 8 | rundu
# Processing Record 8 of Set 8 | tumcon
# City not found. Skipping...
# Processing Record 9 of Set 8 | quang ngai
# Processing Record 10 of Set 8 | mucurapo
# Processing Record 11 of Set 8 | puka
# Processing Record 12 of Set 8 | millinocket
# Processing Record 13 of Set 8 | progreso
# Processing Record 14 of Set 8 | laurel
# Processing Record 15 of Set 8 | temaraia
# City not found. Skipping...
# Processing Record 16 of Set 8 | lazaro cardenas
# Processing Record 17 of Set 8 | boende
# Processing Record 18 of Set 8 | harlingen
# Processing Record 19 of Set 8 | banjar
# Processing Record 20 of Set 8 | kandla
# Processing Record 21 of Set 8 | omaruru
# Processing Record 22 of Set 8 | shingu
# Processing Record 23 of Set 8 | rock sound
# Processing Record 24 of Set 8 | kamogawa
# Processing Record 25 of Set 8 | vanavara
# Processing Record 26 of Set 8 | zhezkazgan
# Processing Record 27 of Set 8 | mao
# Processing Record 28 of Set 8 | salvador
# Processing Record 29 of Set 8 | yagodnoye
# Processing Record 30 of Set 8 | poronaysk
# Processing Record 31 of Set 8 | scottsburgh
# City not found. Skipping...
# Processing Record 32 of Set 8 | bilibino
# Processing Record 33 of Set 8 | kysyl-syr
# Processing Record 34 of Set 8 | salto
# Processing Record 35 of Set 8 | lompoc
# Processing Record 36 of Set 8 | kruisfontein
# Processing Record 37 of Set 8 | russkaya polyana
# Processing Record 38 of Set 8 | trairi
# Processing Record 39 of Set 8 | zatyshshya
# Processing Record 40 of Set 8 | port-cartier
# Processing Record 41 of Set 8 | chumikan
# Processing Record 42 of Set 8 | contamana
# Processing Record 43 of Set 8 | la libertad
# Processing Record 44 of Set 8 | martina franca
# Processing Record 45 of Set 8 | mosetse
# Processing Record 46 of Set 8 | nikolskoye
# Processing Record 47 of Set 8 | katima mulilo
# Processing Record 48 of Set 8 | quatre cocos
# Processing Record 49 of Set 8 | aswan
# Processing Record 50 of Set 8 | bauchi
# Processing Record 1 of Set 9 | codrington
# Processing Record 2 of Set 9 | moussoro
# Processing Record 3 of Set 9 | leningradskiy
# Processing Record 4 of Set 9 | west bay
# Processing Record 5 of Set 9 | nizhniy tsasuchey
# Processing Record 6 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 7 of Set 9 | kalmunai
# Processing Record 8 of Set 9 | backo gradiste
# Processing Record 9 of Set 9 | bengkulu
# Processing Record 10 of Set 9 | sao paulo de olivenca
# Processing Record 11 of Set 9 | igarka
# Processing Record 12 of Set 9 | temiscaming
# Processing Record 13 of Set 9 | port hawkesbury
# Processing Record 14 of Set 9 | port hardy
# Processing Record 15 of Set 9 | neepawa
# Processing Record 16 of Set 9 | noyabrsk
# Processing Record 17 of Set 9 | yongchang
# Processing Record 18 of Set 9 | dargaville
# Processing Record 19 of Set 9 | panji
# Processing Record 20 of Set 9 | kesan
# Processing Record 21 of Set 9 | bilma
# Processing Record 22 of Set 9 | solovetskiy
# City not found. Skipping...
# Processing Record 23 of Set 9 | champerico
# Processing Record 24 of Set 9 | balaipungut
# Processing Record 25 of Set 9 | orchard homes
# Processing Record 26 of Set 9 | san blas
# Processing Record 27 of Set 9 | lensk
# Processing Record 28 of Set 9 | breves
# Processing Record 29 of Set 9 | cameron park
# Processing Record 30 of Set 9 | dhidhdhoo
# Processing Record 31 of Set 9 | marawi
# Processing Record 32 of Set 9 | cap malheureux
# Processing Record 33 of Set 9 | maputo
# Processing Record 34 of Set 9 | khandyga
# Processing Record 35 of Set 9 | porto novo
# Processing Record 36 of Set 9 | saurimo
# Processing Record 37 of Set 9 | omama
# Processing Record 38 of Set 9 | iranshahr
# Processing Record 39 of Set 9 | plaisance-du-touch
# Processing Record 40 of Set 9 | bondo
# Processing Record 41 of Set 9 | taburi
# City not found. Skipping...
# Processing Record 42 of Set 9 | santa maria da boa vista
# Processing Record 43 of Set 9 | hambantota
# Processing Record 44 of Set 9 | craigieburn
# Processing Record 45 of Set 9 | hasaki
# Processing Record 46 of Set 9 | zvishavane
# Processing Record 47 of Set 9 | zhicheng
# Processing Record 48 of Set 9 | grand gaube
# Processing Record 49 of Set 9 | saskylakh
# Processing Record 50 of Set 9 | pasighat
# Processing Record 1 of Set 10 | imperia
# Processing Record 2 of Set 10 | mogadishu
# Processing Record 3 of Set 10 | mackay
# Processing Record 4 of Set 10 | trat
# Processing Record 5 of Set 10 | magdagachi
# Processing Record 6 of Set 10 | fevralsk
# City not found. Skipping...
# Processing Record 7 of Set 10 | damaturu
# Processing Record 8 of Set 10 | tandil
# Processing Record 9 of Set 10 | wolnzach
# Processing Record 10 of Set 10 | almaznyy
# Processing Record 11 of Set 10 | igrim
# Processing Record 12 of Set 10 | coquimbo
# Processing Record 13 of Set 10 | shumskiy
# Processing Record 14 of Set 10 | najran
# Processing Record 15 of Set 10 | ndele
# Processing Record 16 of Set 10 | sao felix do xingu
# Processing Record 17 of Set 10 | murdochville
# Processing Record 18 of Set 10 | iralaya
# Processing Record 19 of Set 10 | marseille
# Processing Record 20 of Set 10 | bollene
# Processing Record 21 of Set 10 | katangli
# Processing Record 22 of Set 10 | ende
# Processing Record 23 of Set 10 | sistranda
# Processing Record 24 of Set 10 | longyearbyen
# Processing Record 25 of Set 10 | verkhoyansk
# Processing Record 26 of Set 10 | lady frere
# Processing Record 27 of Set 10 | xining
# Processing Record 28 of Set 10 | udachnyy
# Processing Record 29 of Set 10 | calgary
# Processing Record 30 of Set 10 | huangmei
# Processing Record 31 of Set 10 | natitingou
# Processing Record 32 of Set 10 | russell
# Processing Record 33 of Set 10 | avera
# Processing Record 34 of Set 10 | hofn
# Processing Record 35 of Set 10 | iroquois falls
# Processing Record 36 of Set 10 | tautira
# Processing Record 37 of Set 10 | rio grande
# Processing Record 38 of Set 10 | camacha
# Processing Record 39 of Set 10 | kabinda
# Processing Record 40 of Set 10 | albion
# Processing Record 41 of Set 10 | pala
# Processing Record 42 of Set 10 | skelleftea
# Processing Record 43 of Set 10 | atikokan
# Processing Record 44 of Set 10 | hobyo
# Processing Record 45 of Set 10 | khudumelapye
# Processing Record 46 of Set 10 | krasnoyarsk-66
# City not found. Skipping...
# Processing Record 47 of Set 10 | luena
# Processing Record 48 of Set 10 | oktyabrskoye
# Processing Record 49 of Set 10 | sandy bay
# Processing Record 50 of Set 10 | nizhniy baskunchak
# Processing Record 1 of Set 11 | cockburn town
# Processing Record 2 of Set 11 | pag
# Processing Record 3 of Set 11 | jawhar
# Processing Record 4 of Set 11 | hamilton
# Processing Record 5 of Set 11 | leeuwarden
# Processing Record 6 of Set 11 | kirkwood
# Processing Record 7 of Set 11 | ballina
# Processing Record 8 of Set 11 | kinablangan
# Processing Record 9 of Set 11 | asau
# Processing Record 10 of Set 11 | cutro
# Processing Record 11 of Set 11 | tazovskiy
# Processing Record 12 of Set 11 | yulara
# Processing Record 13 of Set 11 | umm kaddadah
# Processing Record 14 of Set 11 | winnemucca
# Processing Record 15 of Set 11 | mitu
# Processing Record 16 of Set 11 | capao da canoa
# Processing Record 17 of Set 11 | goba
# Processing Record 18 of Set 11 | selma
# Processing Record 19 of Set 11 | zyryanka
# Processing Record 20 of Set 11 | taoudenni
# Processing Record 21 of Set 11 | mount gambier
# Processing Record 22 of Set 11 | rawannawi
# City not found. Skipping...
# Processing Record 23 of Set 11 | sault sainte marie
# Processing Record 24 of Set 11 | tomigusuku
# Processing Record 25 of Set 11 | buraydah
# Processing Record 26 of Set 11 | nouadhibou
# Processing Record 27 of Set 11 | changji
# Processing Record 28 of Set 11 | knysna
# Processing Record 29 of Set 11 | miandoab
# Processing Record 30 of Set 11 | makakilo city
# Processing Record 31 of Set 11 | grindavik
# Processing Record 32 of Set 11 | yunjinghong
# City not found. Skipping...
# Processing Record 33 of Set 11 | urcos
# Processing Record 34 of Set 11 | rawson
# Processing Record 35 of Set 11 | vestmannaeyjar
# Processing Record 36 of Set 11 | takoradi
# Processing Record 37 of Set 11 | nelson bay
# Processing Record 38 of Set 11 | bossangoa
# Processing Record 39 of Set 11 | acarau
# Processing Record 40 of Set 11 | rypefjord
# Processing Record 41 of Set 11 | jardim
# Processing Record 42 of Set 11 | ust-barguzin
# Processing Record 43 of Set 11 | maykain
# City not found. Skipping...
# Processing Record 44 of Set 11 | terra santa
# Processing Record 45 of Set 11 | dukat
# Processing Record 46 of Set 11 | hutchinson
# Processing Record 47 of Set 11 | tiarei
# Processing Record 48 of Set 11 | cermik
# Processing Record 49 of Set 11 | matara
# Processing Record 50 of Set 11 | sungurlu
# Processing Record 1 of Set 12 | cherskiy
# Processing Record 2 of Set 12 | jacareacanga
# Processing Record 3 of Set 12 | goianesia
# Processing Record 4 of Set 12 | pakxan
# Processing Record 5 of Set 12 | bara
# Processing Record 6 of Set 12 | gat
# Processing Record 7 of Set 12 | sabang
# Processing Record 8 of Set 12 | qasigiannguit
# Processing Record 9 of Set 12 | bonthe
# Processing Record 10 of Set 12 | wageningen
# Processing Record 11 of Set 12 | mahanoro
# Processing Record 12 of Set 12 | padilla
# Processing Record 13 of Set 12 | ruthin
# Processing Record 14 of Set 12 | madang
# Processing Record 15 of Set 12 | ternate
# Processing Record 16 of Set 12 | la palma
# Processing Record 17 of Set 12 | lerwick
# Processing Record 18 of Set 12 | ancud
# Processing Record 19 of Set 12 | witu
# Processing Record 20 of Set 12 | porto empedocle
# Processing Record 21 of Set 12 | biak
# Processing Record 22 of Set 12 | oyama
# Processing Record 23 of Set 12 | isangel
# Processing Record 24 of Set 12 | shenjiamen
# Processing Record 25 of Set 12 | okha
# Processing Record 26 of Set 12 | monrovia
# Processing Record 27 of Set 12 | kaele
# Processing Record 28 of Set 12 | kununurra
# Processing Record 29 of Set 12 | sao joao batista
# Processing Record 30 of Set 12 | taksimo
# Processing Record 31 of Set 12 | korla
# Processing Record 32 of Set 12 | solnechnyy
# Processing Record 33 of Set 12 | khasan
# Processing Record 34 of Set 12 | samarai
# Processing Record 35 of Set 12 | port lincoln
# Processing Record 36 of Set 12 | barbar
# City not found. Skipping...
# Processing Record 37 of Set 12 | faya
# Processing Record 38 of Set 12 | ndola
# Processing Record 39 of Set 12 | pangnirtung
# Processing Record 40 of Set 12 | kaeo
# Processing Record 41 of Set 12 | antalaha
# Processing Record 42 of Set 12 | kuusamo
# Processing Record 43 of Set 12 | lima
# Processing Record 44 of Set 12 | antonina
# Processing Record 45 of Set 12 | shimoda
# Processing Record 46 of Set 12 | tukrah
# Processing Record 47 of Set 12 | ko samui
# Processing Record 48 of Set 12 | south lake tahoe
# Processing Record 49 of Set 12 | sokoni
# Processing Record 50 of Set 12 | shelbyville
# Processing Record 1 of Set 13 | mancio lima
# Processing Record 2 of Set 13 | klichka
# Processing Record 3 of Set 13 | maymanak
# City not found. Skipping...
# Processing Record 4 of Set 13 | kenora
# Processing Record 5 of Set 13 | perigueux
# Processing Record 6 of Set 13 | wajima
# Processing Record 7 of Set 13 | toamasina
# Processing Record 8 of Set 13 | rapid valley
# Processing Record 9 of Set 13 | sur
# Processing Record 10 of Set 13 | katsuura
# Processing Record 11 of Set 13 | olinda
# Processing Record 12 of Set 13 | roebourne
# Processing Record 13 of Set 13 | shimanovsk
# Processing Record 14 of Set 13 | waipawa
# Processing Record 15 of Set 13 | santa marta
# Processing Record 16 of Set 13 | tarakan
# Processing Record 17 of Set 13 | lac du bonnet
# Processing Record 18 of Set 13 | seymchan
# Processing Record 19 of Set 13 | eyl
# Processing Record 20 of Set 13 | scottsbluff
# Processing Record 21 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 22 of Set 13 | smithers
# Processing Record 23 of Set 13 | kuche
# City not found. Skipping...
# Processing Record 24 of Set 13 | karabulak
# Processing Record 25 of Set 13 | sukhumi
# Processing Record 26 of Set 13 | emerald
# Processing Record 27 of Set 13 | jaca
# Processing Record 28 of Set 13 | olafsvik
# Processing Record 29 of Set 13 | roald
# Processing Record 30 of Set 13 | mrirt
# City not found. Skipping...
# Processing Record 31 of Set 13 | krasnoarmeysk
# Processing Record 32 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 33 of Set 13 | port blair
# Processing Record 34 of Set 13 | okhotsk
# Processing Record 35 of Set 13 | colonial park
# Processing Record 36 of Set 13 | redcar
# Processing Record 37 of Set 13 | along
# Processing Record 38 of Set 13 | general roca
# Processing Record 39 of Set 13 | ullal
# Processing Record 40 of Set 13 | mildura
# Processing Record 41 of Set 13 | vila velha
# Processing Record 42 of Set 13 | celica
# Processing Record 43 of Set 13 | prince albert
# Processing Record 44 of Set 13 | starkville
# Processing Record 45 of Set 13 | belozerskoye
# Processing Record 46 of Set 13 | abnub
# Processing Record 47 of Set 13 | ayr
# Processing Record 48 of Set 13 | hudiksvall
# Processing Record 49 of Set 13 | ostrovnoy
# Processing Record 50 of Set 13 | kulachi
# Processing Record 1 of Set 14 | harper
# Processing Record 2 of Set 14 | el vigia
# Processing Record 3 of Set 14 | jaroslaw
# Processing Record 4 of Set 14 | riyadh
# Processing Record 5 of Set 14 | sudogda
# Processing Record 6 of Set 14 | denpasar
# Processing Record 7 of Set 14 | miandrivazo
# Processing Record 8 of Set 14 | alofi
# Processing Record 9 of Set 14 | filadelfia
# Processing Record 10 of Set 14 | sergeyevka
# Processing Record 11 of Set 14 | fare
# Processing Record 12 of Set 14 | terrace
# Processing Record 13 of Set 14 | sorland
# Processing Record 14 of Set 14 | kupang
# Processing Record 15 of Set 14 | skjervoy
# Processing Record 16 of Set 14 | ayan
# Processing Record 17 of Set 14 | vestmanna
# Processing Record 18 of Set 14 | kavieng
# Processing Record 19 of Set 14 | payo
# Processing Record 20 of Set 14 | kembe
# Processing Record 21 of Set 14 | sungaipenuh
# Processing Record 22 of Set 14 | turayf
# Processing Record 23 of Set 14 | santa vitoria do palmar
# Processing Record 24 of Set 14 | ukiah
# Processing Record 25 of Set 14 | kwinana
# Processing Record 26 of Set 14 | pudozh
# Processing Record 27 of Set 14 | shar
# Processing Record 28 of Set 14 | halifax
# Processing Record 29 of Set 14 | paamiut
# Processing Record 30 of Set 14 | ovalle
# Processing Record 31 of Set 14 | moerai
# Processing Record 32 of Set 14 | dunedin
# Processing Record 33 of Set 14 | isla vista
# Processing Record 34 of Set 14 | tarko-sale
# Processing Record 35 of Set 14 | yumen
# Processing Record 36 of Set 14 | goure
# Processing Record 37 of Set 14 | kautokeino
# Processing Record 38 of Set 14 | verkh-chebula
# Processing Record 39 of Set 14 | stepnyak
# Processing Record 40 of Set 14 | foam lake
# Processing Record 41 of Set 14 | dillon
# Processing Record 42 of Set 14 | betong
# Processing Record 43 of Set 14 | skalistyy
# City not found. Skipping...
# Processing Record 44 of Set 14 | yushu
# Processing Record 45 of Set 14 | agucadoura
# Processing Record 46 of Set 14 | lebedinyy
# Processing Record 47 of Set 14 | ampanihy
# Processing Record 48 of Set 14 | bongor
# Processing Record 49 of Set 14 | luang prabang
# Processing Record 50 of Set 14 | tecpan
# Processing Record 1 of Set 15 | manzanillo
# Processing Record 2 of Set 15 | sao gabriel da cachoeira
# Processing Record 3 of Set 15 | mogzon
# Processing Record 4 of Set 15 | luba
# Processing Record 5 of Set 15 | wulanhaote
# City not found. Skipping...
# Processing Record 6 of Set 15 | oban
# Processing Record 7 of Set 15 | lhokseumawe
# Processing Record 8 of Set 15 | ulladulla
# Processing Record 9 of Set 15 | tucurui
# Processing Record 10 of Set 15 | les cayes
# Processing Record 11 of Set 15 | garoua
# Processing Record 12 of Set 15 | gizo
# Processing Record 13 of Set 15 | corrente
# Processing Record 14 of Set 15 | gambela
# Processing Record 15 of Set 15 | ormara
# Processing Record 16 of Set 15 | lata
# Processing Record 17 of Set 15 | wewak
# Processing Record 18 of Set 15 | flinders
# Processing Record 19 of Set 15 | guicheng
# City not found. Skipping...
# Processing Record 20 of Set 15 | abha
# Processing Record 21 of Set 15 | lethem
# Processing Record 22 of Set 15 | yuanping
# Processing Record 23 of Set 15 | luganville
# Processing Record 24 of Set 15 | urdzhar
# City not found. Skipping...
# Processing Record 25 of Set 15 | bowen
# Processing Record 26 of Set 15 | turangi
# Processing Record 27 of Set 15 | sao jose da coroa grande
# Processing Record 28 of Set 15 | phalaborwa
# Processing Record 29 of Set 15 | benguela
# Processing Record 30 of Set 15 | challapata
# Processing Record 31 of Set 15 | bertinoro
# Processing Record 32 of Set 15 | khilok
# Processing Record 33 of Set 15 | khomeynishahr
# City not found. Skipping...
# Processing Record 34 of Set 15 | omboue
# Processing Record 35 of Set 15 | columbus
# Processing Record 36 of Set 15 | wanlaweyn
# Processing Record 37 of Set 15 | yeppoon
# Processing Record 38 of Set 15 | kazachka
# Processing Record 39 of Set 15 | tuatapere
# Processing Record 40 of Set 15 | khor
# Processing Record 41 of Set 15 | prince rupert
# Processing Record 42 of Set 15 | saint-francois
# Processing Record 43 of Set 15 | honningsvag
# Processing Record 44 of Set 15 | mehamn
# Processing Record 45 of Set 15 | san rafael del sur
# Processing Record 46 of Set 15 | presidente medici
# Processing Record 47 of Set 15 | loreto
# Processing Record 48 of Set 15 | qiyang
# Processing Record 49 of Set 15 | trelew
# Processing Record 50 of Set 15 | ucluelet
# Processing Record 1 of Set 16 | kota tinggi
# Processing Record 2 of Set 16 | gunzenhausen
# Processing Record 3 of Set 16 | xixiang
# Processing Record 4 of Set 16 | toungoo
# City not found. Skipping...
# Processing Record 5 of Set 16 | renala khurd
# Processing Record 6 of Set 16 | dayong
# Processing Record 7 of Set 16 | wanning
# Processing Record 8 of Set 16 | ust-kut
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#              City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0            Sola -13.88  167.55     82.40        78          75       11.41
# 1    Punta Arenas -53.15  -70.92     55.40        66          75       14.99
# 2     Bongandanga   1.50   21.05     70.97        97          98        1.70
# 3     Port Alfred -33.59   26.89     66.90        78          84       22.28
# 4       Mahebourg -20.41   57.70     71.60        64          40       10.29
# ..            ...    ...     ...       ...       ...         ...         ...
# 697       Xixiang  35.16  112.86     55.99        99           0        4.76
# 698  Renala Khurd  30.88   73.60     64.60        25           0        3.58
# 699        Dayong  25.02  118.29     69.80        77           0        2.24
# 700       Wanning  18.80  110.40     70.68        89         100        6.67
# 701       Ust-Kut  56.79  105.77     15.80        87           0        2.95
#
#     Country   Current Description                 Date
# 0        VU         broken clouds  2020-11-01 18:32:42
# 1        CL         broken clouds  2020-11-01 18:32:42
# 2        CD       overcast clouds  2020-11-01 18:32:42
# 3        ZA         broken clouds  2020-11-01 18:32:42
# 4        MU      scattered clouds  2020-11-01 18:29:46
# ..      ...                   ...                  ...
# 697      CN             clear sky  2020-11-01 18:28:28
# 698      PK             clear sky  2020-11-01 18:33:36
# 699      CN             clear sky  2020-11-01 18:33:36
# 700      CN  heavy intensity rain  2020-11-01 18:33:37
# 701      RU             clear sky  2020-11-01 18:32:06
#
# [702 rows x 10 columns]

# %%
#re order o columns
new_column_order = ["City", "Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed", "Current Description"]

# %%
#assigning new order to DF 

city_data_df = city_data_df[new_column_order]

# %%
city_data_df.head(10)
# Out:
#            City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0          Sola      VU -13.88  167.55     82.40        78          75
# 1  Punta Arenas      CL -53.15  -70.92     55.40        66          75
# 2   Bongandanga      CD   1.50   21.05     70.97        97          98
# 3   Port Alfred      ZA -33.59   26.89     66.90        78          84
# 4     Mahebourg      MU -20.41   57.70     71.60        64          40
# 5   New Norfolk      AU -42.78  147.06     53.01        77         100
# 6      Souillac      MU -20.52   57.52     71.60        64          40
# 7         Airai      TL  -8.93  125.41     60.48        82          97
# 8        Albany      US  42.60  -73.97     48.99        73          99
# 9     Omsukchan      RU  62.53  155.80     12.76        93         100
#
#    Wind Speed Current Description
# 0       11.41       broken clouds
# 1       14.99       broken clouds
# 2        1.70     overcast clouds
# 3       22.28       broken clouds
# 4       10.29    scattered clouds
# 5        1.97     overcast clouds
# 6       10.29    scattered clouds
# 7        2.08     overcast clouds
# 8        4.00     overcast clouds
# 9        6.08     overcast clouds

# %%
# Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder
output_data_file = "weather_database/WeatherPy_Database.csv"
# Export the WeatherPy_Database into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
